# %%
# %load_ext tensorboard
# %tensorboard --logdir mae_logs/mae_pretraining
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 23712), started 0:00:54 ago. (Use '!kill 23712' to kill it.)
#       <iframe id="tensorboard-frame-9f96818d125180a9" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-9f96818d125180a9");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
